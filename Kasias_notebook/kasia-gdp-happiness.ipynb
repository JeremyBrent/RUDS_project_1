# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os 
from scipy.stats import sem
import scipy.stats as sts
from scipy.stats import linregress

# %%
csvpath = os.path.join("../Data/GDP_v_satisfaction/gdp_vs_happiness.csv")
gdp_happy_df = pd.read_csv(csvpath)
gdp_happy_df.head()
# Out:
#         Entity Code  Year  GDP per capita (constant 2011 international $)  \
# 0  Afghanistan  AFG  1800                                             NaN
# 1  Afghanistan  AFG  1801                                             NaN
# 2  Afghanistan  AFG  1802                                             NaN
# 3  Afghanistan  AFG  1803                                             NaN
# 4  Afghanistan  AFG  1804                                             NaN
#
#     Life satisfaction (country average; 0-10) (Cantril Ladder (0=worst; 10=best))  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unnamed: 5
# 0   3280000.0
# 1   3280000.0
# 2   3280000.0
# 3   3280000.0
# 4   3280000.0

# %%
gdp_happy_clean = gdp_happy_df.dropna(how="any")
gdp_happy_clean
# Out:
#             Entity Code  Year  GDP per capita (constant 2011 international $)  \
# 208    Afghanistan  AFG  2008                                     1298.143159
# 209    Afghanistan  AFG  2009                                     1531.173993
# 210    Afghanistan  AFG  2010                                     1614.255001
# 211    Afghanistan  AFG  2011                                     1660.739856
# 212    Afghanistan  AFG  2012                                     1839.273579
# ...            ...  ...   ...                                             ...
# 48113     Zimbabwe  ZWE  2013                                     1929.765001
# 48114     Zimbabwe  ZWE  2014                                     1925.138698
# 48115     Zimbabwe  ZWE  2015                                     1912.280261
# 48116     Zimbabwe  ZWE  2016                                     1879.628119
# 48117     Zimbabwe  ZWE  2017                                     1899.774977
#
#         Life satisfaction (country average; 0-10) (Cantril Ladder (0=worst; 10=best))  \
# 208                                             3.723590
# 209                                             4.401778
# 210                                             4.758381
# 211                                             3.831719
# 212                                             3.782938
# ...                                                  ...
# 48113                                           4.690188
# 48114                                           4.184451
# 48115                                           3.703191
# 48116                                           3.735400
# 48117                                           3.638300
#
#        Unnamed: 5
# 208    27722000.0
# 209    28395000.0
# 210    29186000.0
# 211    30117000.0
# 212    31161000.0
# ...           ...
# 48113  13350000.0
# 48114  13587000.0
# 48115  13815000.0
# 48116  14030000.0
# 48117  14237000.0
#
# [1519 rows x 6 columns]

# %%
selected_countries = ["United States","Mexico","Venezuela","Brazil","South Africa","Nigeria","Poland","Sweden","Russia","China","South Korea","Australia"]
gdp_happy_select = gdp_happy_clean[gdp_happy_clean.Entity.isin(selected_countries)]
gdp_happy_select = gdp_happy_select.reset_index(drop=True)
del gdp_happy_select["Unnamed: 5"]

# %%
gdp_happy_select.columns=["Country","Code","Year","GDP","Life sat"]
gdp_happy_select.to_csv("../Output/gdp_lifesat.csv")

# %%
gdp_happy_select_2010 = gdp_happy_select.loc[gdp_happy_select["Year"] == "2010"]
gdp_happy_select_2010
# Out:
#            Country Code  Year           GDP  Life sat
# 3        Australia  AUS  2010  41464.040070  7.450047
# 15          Brazil  BRA  2010  14537.567193  6.837331
# 27           China  CHN  2010   9525.818483  4.652737
# 39          Mexico  MEX  2010  15715.972145  6.802389
# 51         Nigeria  NGA  2010   5150.158818  4.760276
# 60          Poland  POL  2010  21770.644436  5.887030
# 72          Russia  RUS  2010  23107.785221  5.384773
# 84    South Africa  ZAF  2010  11887.805034  4.652429
# 96     South Korea  KOR  2010  30352.104819  6.116024
# 108         Sweden  SWE  2010  42942.562503  7.496019
# 120  United States  USA  2010  49374.178885  7.163616
# 132      Venezuela  VEN  2010  16544.972055  7.478455

# %%
x_values = gdp_happy_select_2010["GDP"]
y_values = gdp_happy_select_2010["Life sat"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.title("GDP vs Life Satisfaction")
plt.xlabel("GDP")
plt.ylabel("Life Satisfaction")

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
# plt.annotate(line_eq,(6,10),fontsize=15,color="red")

print(f"The r-squared is: {rvalue**2}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-0d53437f2fa1> in <module>
# ----> 1 x_values = gdp_happy_select_2010["GDP"]
#       2 y_values = gdp_happy_select_2010["Life sat"]
#       3
#       4 (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
#       5 regress_values = x_values * slope + intercept
#
# NameError: name 'gdp_happy_select_2010' is not defined
